-- %% [markdown]
-- # 📜 _ddl_silver

-- %% [markdown]
-- ## 📐 schemas

-- %%
--DROP SCHEMA silver_comercio_ext_auxiliares CASCADE;
CREATE SCHEMA IF NOT EXISTS silver_comercio_ext_auxiliares
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/';

-- %%
--DROP SCHEMA silver_comercio_ext_estatisticas CASCADE;
CREATE SCHEMA IF NOT EXISTS silver_comercio_ext_estatisticas
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_estatisticas/';

-- %%
--DROP SCHEMA silver_comercio_ext_indices CASCADE;
CREATE SCHEMA IF NOT EXISTS silver_comercio_ext_indices
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/';

-- %%
--DROP SCHEMA silver_entidades_base CASCADE;
CREATE SCHEMA IF NOT EXISTS silver_entidades_base
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/entidades_base/';

-- %%
--DROP SCHEMA silver_entidades_referencias CASCADE;
CREATE SCHEMA IF NOT EXISTS silver_entidades_referencias
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/entidades_referencias/';

-- %% [markdown]
-- ## 📄 tables

-- %% [markdown]
-- ### silver_comercio_ext_estatisticas

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_estatisticas.tb_exportacoes (
  CO_ANO INT COMMENT 'Ano em que a exportação ocorreu',
  CO_MES INT COMMENT 'Mês de referência da exportação',
  CO_NCM STRING COMMENT 'Código do produto exportado (NCM)',
  CO_UNID STRING COMMENT 'Unidade oficial usada para o produto',
  CO_PAIS STRING COMMENT 'País de destino da exportação',
  SG_UF_NCM STRING COMMENT 'Estado brasileiro exportador',
  CO_VIA STRING COMMENT 'Meio de transporte utilizado',
  CO_URF STRING COMMENT 'Unidade da Receita Federal responsável',
  QT_ESTAT DECIMAL(18,2) COMMENT 'Quantidade na unidade estatística do NCM',
  KG_LIQUIDO DECIMAL (18,3) COMMENT 'Peso total exportado (kg)',
  VL_FOB DECIMAL (18,2) COMMENT 'Valor da mercadoria na exportação (US$)',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Base de exportações brasileiras agregada mensalmente (MDIC/Comex Stat)'
PARTITIONED BY (CO_ANO, CO_MES)
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_estatisticas/tb_exportacoes'
TBLPROPERTIES (
  delta.autoOptimize.optimizeWrite = true,
  delta.autoOptimize.autoCompact = true,
  'layer' = 'silver',
  'source' = 'landingbeca2026jan',
  'type' = 'fact',
  'contains_sensitive_data' = 'false'
);

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_estatisticas.tb_exportacoes_municipios (
  CO_ANO INT COMMENT 'Ano em que a exportação ocorreu',
  CO_MES INT COMMENT 'Mês de referência da exportação',
  SH4 STRING COMMENT 'Capítulo SH4 do produto',
  CO_PAIS STRING COMMENT 'País de destino da exportação',
  SG_UF_NCM STRING COMMENT 'Estado brasileiro exportador',
  CO_MUN STRING COMMENT 'Código do município',
  KG_LIQUIDO DECIMAL (18,3) COMMENT 'Peso total exportado (kg)',
  VL_FOB DECIMAL (18,2) COMMENT 'Valor da mercadoria na exportação (US$)',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Base de exportações brasileiras agregada mensalmente (MDIC/Comex Stat)'
PARTITIONED BY (CO_ANO, CO_MES)
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_estatisticas/tb_exportacoes_municipios'
TBLPROPERTIES (
  delta.autoOptimize.optimizeWrite = true,
  delta.autoOptimize.autoCompact = true,
  'layer' = 'silver',
  'source' = 'landingbeca2026jan',
  'type' = 'fact',
  'contains_sensitive_data' = 'false'
);

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_estatisticas.tb_importacoes (
  CO_ANO INT COMMENT 'Ano em que a importação ocorreu',
  CO_MES INT COMMENT 'Mês de referência da importação',
  CO_NCM STRING COMMENT 'Código do produto importado (NCM)',
  CO_UNID STRING COMMENT 'Unidade oficial usada para o produto',
  CO_PAIS STRING COMMENT 'País de origem da mercadoria',
  SG_UF_NCM STRING COMMENT 'Estado brasileiro de destino',
  CO_VIA STRING COMMENT 'Meio de transporte utilizado',
  CO_URF STRING COMMENT 'Unidade da Receita Federal responsável',
  QT_ESTAT DECIMAL (18,2) COMMENT 'Quantidade na unidade estatística do NCM',
  KG_LIQUIDO DECIMAL (18,3) COMMENT 'Peso total importado (kg)',
  VL_FOB DECIMAL (18,2) COMMENT 'Valor da mercadoria importada (US$)',
  VL_FRETE DECIMAL (18,2) COMMENT 'Custo de transporte internacional (US$)',
  VL_SEGURO DECIMAL (18,2) COMMENT 'Custo do seguro internacional (US$)',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Base de importações brasileiras agregada mensalmente (MDIC/Comex Stat)'
PARTITIONED BY (CO_ANO, CO_MES)
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_estatisticas/tb_importacoes'
TBLPROPERTIES (
  delta.autoOptimize.optimizeWrite = true,
  delta.autoOptimize.autoCompact = true,
  'layer' = 'silver',
  'source' = 'landingbeca2026jan',
  'type' = 'fact',
  'contains_sensitive_data' = 'false'
);

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_estatisticas.tb_importacoes_municipios (
  CO_ANO INT COMMENT 'Ano em que a importação ocorreu',
  CO_MES INT COMMENT 'Mês de referência da importação',
  CO_NCM STRING COMMENT 'Código do produto importado (NCM)',
  CO_UNID STRING COMMENT 'Unidade oficial usada para o produto',
  CO_PAIS STRING COMMENT 'País de origem da mercadoria',
  SG_UF_NCM STRING COMMENT 'Estado brasileiro de destino',
  CO_VIA STRING COMMENT 'Meio de transporte utilizado',
  CO_URF STRING COMMENT 'Unidade da Receita Federal responsável',
  QT_ESTAT DOUBLE COMMENT 'Quantidade na unidade estatística do NCM',
  KG_LIQUIDO DOUBLE COMMENT 'Peso total importado (kg)',
  VL_FOB DOUBLE COMMENT 'Valor da mercadoria importada (US$)',
  VL_FRETE DOUBLE COMMENT 'Custo de transporte internacional (US$)',
  VL_SEGURO DOUBLE COMMENT 'Custo do seguro internacional (US$)',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Base de importações brasileiras agregada mensalmente (MDIC/Comex Stat)'
PARTITIONED BY (CO_ANO, CO_MES)
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_estatisticas/tb_importacoes'
TBLPROPERTIES (
  delta.autoOptimize.optimizeWrite = true,
  delta.autoOptimize.autoCompact = true,
  'layer' = 'silver',
  'source' = 'landingbeca2026jan',
  'type' = 'fact',
  'contains_sensitive_data' = 'false'
);

-- %% [markdown]
-- ### silver_comercio_ext_indices

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_nomenclatura_brasileira (
  CO_NBM STRING COMMENT 'Código do produto na Nomenclatura Brasileira de Mercadorias',
  NO_NBM STRING COMMENT 'Descrição textual do item conforme NBM',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Tabela de dimensão legado para códigos NBM'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_nomenclatura_brasileira'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_nomenclatura_mercosul (
  CO_NCM STRING COMMENT 'Código da Nomenclatura Comum do Mercosul',
  NO_NCM STRING COMMENT 'Descrição do produto',
  CO_UNID STRING COMMENT 'Código da unidade estatística',
  CO_SH6 STRING COMMENT 'Código do Sistema Harmonizado nível 6',
  CO_PPE STRING COMMENT 'Código de classificação PPE',
  CO_PPI STRING COMMENT 'Código de classificação PPI',
  CO_CUCI_ITEM STRING COMMENT 'Código de classificação CUCI',
  CO_CGCE_N3 STRING COMMENT 'Código de classificação CGCE nível 3',
  CO_ISIC_CLASSE STRING COMMENT 'Código de atividade econômica ISIC',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Dimensão principal de produtos (NCM) e suas diversas classificações econômicas'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_nomenclatura_mercosul'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_isic_cuci (
  CO_ISIC_SECAO STRING COMMENT 'Código da seção ISIC (Macroatividade econômica)',
  NO_ISIC_SECAO STRING COMMENT 'Descrição da atividade econômica ISIC',
  CO_CUCI_GRUPO STRING COMMENT 'Código do grupo internacional de produtos CUCI',
  NO_CUCI_GRUPO STRING COMMENT 'Tipo de bem comercializado (CUCI)'
)
USING DELTA
COMMENT 'Classificação econômica internacional relacionando atividades (ISIC) e produtos (CUCI)'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_isic_cuci'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_nbm (
  CO_NBM STRING COMMENT 'Código legado do item (NBM)',
  CO_NCM STRING COMMENT 'Código padronizado atual equivalente (NCM)',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Mapeamento (bridge) entre códigos legados NBM e atuais NCM'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_nbm'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_cgce (
  CO_CGCE_N3 STRING COMMENT 'Código CGCE nível 3 (detalhado)',
  NO_CGCE_N3 STRING COMMENT 'Nome da categoria econômica (PT)',
  NO_CGCE_N3_ING STRING,
  NO_CGCE_N3_ESP STRING,
  CO_CGCE_N2 STRING COMMENT 'Código CGCE nível 2',
  NO_CGCE_N2 STRING COMMENT 'Nome do grupo econômico (PT)',
  NO_CGCE_N2_ING STRING,
  NO_CGCE_N2_ESP STRING,
  CO_CGCE_N1 STRING COMMENT 'Código CGCE nível 1 (Macro)',
  NO_CGCE_N1 STRING COMMENT 'Nome da macro-categoria (PT)',
  NO_CGCE_N1_ING STRING,
  NO_CGCE_N1_ESP STRING,
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Hierarquia de classificação econômica CGCE'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_cgce'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_cuci (
  CO_CUCI_ITEM STRING COMMENT 'Nível mais detalhado da classificação internacional',
  NO_CUCI_ITEM STRING COMMENT 'Nome do item comercializado',
  CO_CUCI_SUB STRING COMMENT 'Cóifigo Subgrupo CUCI',
  NO_CUCI_SUB STRING COMMENT 'Nome do Subgrupo CUCI',
  CO_CUCI_GRUPO STRING COMMENT 'Código Grupo CUCI',
  NO_CUCI_GRUPO STRING COMMENT 'Nome do Grupo CUCI',
  CO_CUCI_DIVISAO STRING COMMENT 'Código Divisão CUCI',
  NO_CUCI_DIVISAO STRING COMMENT 'Nome da Divisão CUCI',
  CO_CUCI_SEC STRING COMMENT 'Macrogrupo CUCI (Seção)',
  NO_CUCI_SEC STRING COMMENT 'Nome da Seção CUCI',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Hierarquia completa da classificação internacional CUCI'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_cuci'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_isic (
  CO_ISIC_CLASSE STRING COMMENT 'Nível detalhado da atividade econômica',
  NO_ISIC_CLASSE STRING COMMENT 'Descrição da atividade (PT)',
  NO_ISIC_CLASSE_ING STRING COMMENT 'Descrição da atividade em Inglês',
  NO_ISIC_CLASSE_ESP STRING COMMENT 'Descrição da atividade em Espanhol',
  CO_ISIC_GRUPO STRING COMMENT 'Nível intermediário da atividade econômica',
  NO_ISIC_GRUPO STRING COMMENT 'Descrição do grupo econômico (PT)',
  NO_ISIC_GRUPO_ING STRING COMMENT 'Descrição do grupo econômico em Inglês',
  NO_ISIC_GRUPO_ESP STRING COMMENT 'Descrição do grupo econômico em Espanhol',
  CO_ISIC_DIVISAO STRING COMMENT 'Nível mais alto da atividade econômica',
  NO_ISIC_DIVISAO STRING COMMENT 'Descrição do setor econômico (PT)',
  NO_ISIC_DIVISAO_ING STRING COMMENT 'Descrição do setor econômico em Inglês',
  NO_ISIC_DIVISAO_ESP STRING COMMENT 'Descrição do setor econômico em Espanhol',
  CO_ISIC_SECAO STRING COMMENT 'Macrosetor da atividade econômica',
  NO_ISIC_SECAO STRING COMMENT 'Descrição da seção econômica (PT)',
  NO_ISIC_SECAO_ING STRING COMMENT 'Descrição da seção econômica em Inglês',
  NO_ISIC_SECAO_ESP STRING COMMENT 'Descrição da seção econômica em Espanhol',
  TS_REF TIMESTAMP COMMENT 'Data de referência da tabela',
  NM_ORIGEM STRING COMMENT 'Fonte da tabela'
)
USING DELTA
COMMENT 'Hierarquia da classificação de atividades econômicas ISIC'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_isic'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_ppe (
  CO_PPE STRING COMMENT 'Identificador da categoria PPE',
  NO_PPE STRING COMMENT 'Descrição da categoria em Português',
  NO_PPE_MIN STRING COMMENT 'Descrição da categoria em Português (minúsculo)',
  NO_PPE_ING STRING COMMENT 'Descrição da categoria em Inglês'
)
USING DELTA
COMMENT 'Dicionário da classificação PPE (Perfil Produtivo)'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_ppe'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_ppi (
  CO_PPI STRING COMMENT 'Identificador da categoria PPI',
  NO_PPI STRING COMMENT 'Descrição em Português',
  NO_PPI_MIN STRING COMMENT 'Descrição em Português (minúsculo)',
  NO_PPI_ING STRING COMMENT 'Descrição em Inglês'
)
USING DELTA
COMMENT 'Dicionário da classificação PPI'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_ppi'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_sh (
  CO_SH6 STRING COMMENT 'Subposição internacional (6 dígitos)',
  NO_SH6_POR STRING COMMENT 'Nome da subposição internacional em Português',
  NO_SH6_ESP STRING COMMENT 'Nome da subposição internacional em Espanhol',
  NO_SH6_ING STRING COMMENT 'Nome da subposição internacional em Inglês',
  CO_SH4 STRING COMMENT 'Posição (4 dígitos)',
  NO_SH4_POR STRING COMMENT 'Nome da posição em Português',
  NO_SH4_ESP STRING COMMENT 'Nome da posição em Espanhol',
  NO_SH4_ING STRING COMMENT 'Nome da posição em Inglês',
  CO_SH2 STRING COMMENT 'Capítulo (2 dígitos)',
  NO_SH2_POR STRING COMMENT 'Nome do capítulo em Português',
  NO_SH2_ESP STRING COMMENT 'Nome do capítulo em Espanhol',
  NO_SH2_ING STRING COMMENT 'Nome do capítulo em Inglês',
  CO_NCM_SECROM STRING COMMENT 'Código da seção (Romano)',
  NO_SEC_POR STRING COMMENT 'Nome macro da seção em Português',
  NO_SEC_ESP STRING COMMENT 'Nome macro da seção em Espanhol',
  NO_SEC_ING STRING COMMENT 'Nome macro da seção em Inglês'
)
USING DELTA
COMMENT 'Hierarquia do Sistema Harmonizado (SH/HS) do nível 2 ao 6'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_sh'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_indices.tb_referencia_ncm_unidade (
  CO_UNID STRING COMMENT 'Código da unidade estatística',
  NO_UNID STRING COMMENT 'Nome por extenso da unidade',
  SG_UNID STRING COMMENT 'Abreviação/Sigla da unidade'
)
USING DELTA
COMMENT 'Tabela de referência de unidades de medida estatísticas'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_unidade'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %% [markdown]
-- ### silver_comercio_ext_auxiliares

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_auxiliar_paises (
  CO_PAIS        STRING COMMENT 'Código interno do país',
  CO_PAIS_ISON3  STRING COMMENT 'Código ISO numérico (3)',
  CO_PAIS_ISOA3  STRING COMMENT 'Código ISO alfabético (3)',
  NO_PAIS        STRING COMMENT 'Nome do país (PT)',
  NO_PAIS_ING    STRING COMMENT 'Nome do país (EN)',
  NO_PAIS_ESP    STRING COMMENT 'Nome do país (ES)'
)
USING DELTA
COMMENT 'Referência de Países com códigos ISO e nomes multilíngues (PT/EN/ES)'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_auxiliar_paises'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_auxiliar_vias (
  CO_VIA STRING COMMENT 'Código da via de transporte',
  NO_VIA STRING COMMENT 'Nome da via de transporte'
)
USING DELTA
COMMENT 'Referência de Vias de Transporte'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_auxiliar_vias'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_auxiliar_recintos_alfandegarios (
  CO_URF STRING COMMENT 'Código URF (recinto alfandegário)',
  NO_URF STRING COMMENT 'Nome do URF'
)
USING DELTA
COMMENT 'Referência de URF (recintos alfandegários)'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_auxiliar_recintos_alfandegarios'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_auxiliar_unidades_federativas (
  CO_UF STRING COMMENT 'Código da UF',
  SG_UF STRING COMMENT 'Sigla da UF',
  NO_UF STRING COMMENT 'Nome da UF',
  NO_REGIAO STRING COMMENT 'Nome da região'
)
USING DELTA
COMMENT 'Referência de UFs (unidades federativas) e região'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_auxiliar_unidades_federativas'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_auxiliar_vias (
  CO_VIA STRING COMMENT 'Código da via de transporte',
  NO_VIA STRING COMMENT 'Nome da via de transporte'
)
USING DELTA
COMMENT 'Referência de Vias de Transporte'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_auxiliar_vias'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_referencia_pais_bloco (
  CO_PAIS STRING COMMENT 'Código do país',
  CO_BLOCO STRING COMMENT 'Código do bloco',
  NO_BLOCO STRING COMMENT 'Nome do bloco (PT)',
  NO_BLOCO_ING STRING COMMENT 'Nome do bloco (EN)',
  NO_BLOCO_ESP STRING COMMENT 'Nome do bloco (ES)'
)
USING DELTA
COMMENT 'Referência de Blocos Econômicos por País'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_referencia_pais_bloco'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');

-- %%
CREATE EXTERNAL TABLE IF NOT EXISTS silver_comercio_ext_auxiliares.tb_referencia_uf_mun (
  CO_MUN_GEO STRING COMMENT 'Código geográfico do município (IBGE/geo)',
  NO_MUN STRING COMMENT 'Nome do município',
  NO_MUN_MIN STRING COMMENT 'Nome do município (minúsculo/padronizado)',
  SG_UF STRING COMMENT 'Sigla da UF'
)
USING DELTA
COMMENT 'Referência de Municípios com código geográfico e UF'
LOCATION 'abfss://silver@storagedatanexus.dfs.core.windows.net/landingbeca2026jan/comercio_ext_auxiliares/tb_referencia_uf_mun'
TBLPROPERTIES ('layer' = 'silver', 'source' = 'landingbeca2026jan', 'type' = 'dimension', 'contains_sensitive_data' = 'false');
