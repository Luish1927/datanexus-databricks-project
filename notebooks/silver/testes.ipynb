// %%
import org . apache . spark  . sql . functions . _
import org . apache . spark  . sql . types . _
import org . apache . spark  . sql . DataFrame
import org . apache . hadoop . fs  . FileSystem 
import org . apache . hadoop . fs  . Path 
import io  . delta  . tables . _

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/landingbeca2026jan/comercio_ext_indices")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/cnaes/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/empresas/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/estabelecimentos/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/motivos/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/municipios/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/naturezas/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/paises/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/qualificacoes/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/simples/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/socios/")
display(dfTest.limit(10))

// %%
val dfTest = spark.read.format("delta").load("/mnt/silver/landingbeca2026jan/comercio_ext_indices/tb_referencia_ncm_sh/")
display(dfTest.limit(10))

// %%
%scala
// Tabela: Exportação 2021
val dfExp2021 = spark.read.format("delta").load(s"$bronzeRoot/EXP_2021_MUN_delta")
display(dfExp2021.limit(10))

// %%
%scala
// Tabela: Importação 2022
val dfImp2022 = spark.read.format("delta").load(s"$bronzeRoot/IMP_2022_MUN_delta")
display(dfImp2022.limit(10))

// %%
%scala
// Tabela: Países
val dfPais = spark.read.format("delta").load(s"$bronzeRoot/PAIS_delta")
display(dfPais.limit(10))

// %%
%scala
// Tabela: Países Bloco
val dfPaisBloco = spark.read.format("delta").load(s"$bronzeRoot/PAIS_BLOCO_delta")
display(dfPaisBloco.limit(10))

// %%
%scala
// Tabela: UF (Unidades da Federação)
val dfUF = spark.read.format("delta").load(s"$bronzeRoot/UF_delta")
display(dfUF.limit(10))

// %%
%scala
// Tabela: Municípios das UF
val dfUFMun = spark.read.format("delta").load(s"$bronzeRoot/UF_MUN_delta")
display(dfUFMun.limit(10))

// %%
%scala
// Tabela: URF (Recintos Alfandegários)
val dfURF = spark.read.format("delta").load(s"$bronzeRoot/URF_delta")
display(dfURF.limit(10))

// %%
%scala
// Tabela: Via de Transporte
val dfVia = spark.read.format("delta").load(s"$bronzeRoot/VIA_delta")
display(dfVia.limit(10))
