# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
# configs de performance

spark.conf.set("spark.sql.sources.partitionOverwriteMode", "dynamic")
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", 10 * 1024 * 1024)

# %%
# paths

path_silver = "abfss://silver@storagedatanexus.dfs.core.windows.net/"
target_table = "gold.rst_exp_imp_uf"

# %%
df_export = spark.read.format("delta").load(path_silver + "landingbeca2026jan/" + "comercio_ext_estatisticas/" + "tb_exportacoes") \
    .select(
        "CO_ANO", 
        "CO_MES", 
        "SG_UF_NCM",
        "CO_NCM", 
        "VL_FOB", 
    )

# %%
potenicla exportador
indice de atratividade
