# %% [markdown]
# #Ingestão de arquivos para raw

# %% [markdown]
# ## Paremtros

# %%
# %run /Workspace/Shared/build/Parametros_Ingest

# %% [markdown]
# ## Imports

# %%
import pyspark.sql.functions as F

# %%
df_cnpj = (
    spark . readStream
    . format ( "cloudFiles" )
    . option ( "cloudFiles.format", "csv" )
    . option ( "header", "true" )
    . option ( "delimiter", ";" )
    . option ( "cloudFiles.inferColumnTypes", "true" )
    . option ( "compression", ".zip" )
    . load ( caminho_cnpj )
)
