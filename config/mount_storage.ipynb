# %%
# config do mnt

configs = {
  "fs.azure.account.key.storagedatanexus.blob.core.windows.net": dbutils.secrets.get("kv-datanexus", "storagedatanexus")
}

dbutils.fs.mount(
    source = "wasbs://raw@storagedatanexus.blob.core.windows.net",
    mount_point = "/mnt/raw",
    extra_configs = configs
)
dbutils.fs.mount(
    source = "wasbs://bronze@storagedatanexus.blob.core.windows.net",
    mount_point = "/mnt/bronze",
    extra_configs = configs
)
dbutils.fs.mount(
    source = "wasbs://silver@storagedatanexus.blob.core.windows.net",
    mount_point = "/mnt/silver",
    extra_configs = configs
)
dbutils.fs.mount(
    source = "wasbs://gold@storagedatanexus.blob.core.windows.net",
    mount_point = "/mnt/gold",
    extra_configs = configs
)

dbutils.fs.mount(
    source = "wasbs://metastore@storagedatanexus.blob.core.windows.net",
    mount_point = "/mnt/metastore",
    extra_configs = configs
)
